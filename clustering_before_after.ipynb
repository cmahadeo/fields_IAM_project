# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from clustering_pre_post_toxicdetection import complete_entitlement_cleaning_pipeline

# %%
data=pd.read_csv('data/data.csv')

# %%
original_results, cleaned_results, summary_df, binarized_data, cleaned_data, toxic_combinations = complete_entitlement_cleaning_pipeline(data, 'department_anomaly_results')
# Out:
# 🚀 Starting complete entitlement cleaning and clustering pipeline...
# ...
# 📁 Detected directory path, using: department_anomaly_results/all_departments_combined.csv
#
# 1️⃣  STEP 1: Loading toxic combinations from: department_anomaly_results/all_departments_combined.csv
# 🔍 Loading toxic combinations from single file: 'department_anomaly_results/all_departments_combined.csv'...
# 📊 Loaded 204814 combinations from all_departments_combined.csv
# 📋 Columns: ['combination_id', 'entitlement_1', 'entitlement_2', 'entitlement_1_name', 'entitlement_2_name', 'frequency', 'log_frequency', 'is_rare', 'max_risk', 'min_risk', 'avg_risk', 'risk_difference', 'both_high_risk', 'max_criticality', 'avg_criticality', 'same_application', 'same_type', 'same_function', 'cross_function_high_risk', 'combined_risk_score', 'cluster', 'distance_to_center', 'is_anomaly', 'anomaly_score', 'batch_id', 'processing_timestamp', 'department', 'department_employees', 'department_entitlements', 'toxic']
# ...

# %%
print(summary_df)
# Out:
#                  Department  Employees  Entitlements  Original_Best_K  \
# 0                  Treasury         81          2000                2
# 1                Operations         72          2000                6
# 2           Risk Management         69          2000                3
# 3               Recruitment         58          2000                2
# 4               Credit Risk         54          2000                2
# 5           Human Resources         77          2000                2
# 6                   Finance         71          2000                3
# 7                  Security         63          2000                2
# 8    Information Technology         65          2000                2
# 9            Infrastructure         74          2000                2
# 10               Accounting         66          2000                3
# 11       Financial Planning         62          2000                2
# ...

# %% [markdown]
# # Conclusions

# %% [markdown]
# ### 1. We do not get an improvement in the scores of our clustering by cleaning our toxic combinations
